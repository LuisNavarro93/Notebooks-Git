# %% [markdown]
# # Time Indexed Files `F-10`

# %%
cd ~/Desktop/Tesis/Notebooks-Git
# Out:
# /home/luis/Desktop/Tesis/Notebooks-Git

# %%
import Script as sc

# %%
cd ~/Desktop/Tesis/F10
# Out:
# /home/luis/Desktop/Tesis/F10

# %%
ls
# Out:
#  CSVs/
#  FWR_MUD_nr_002.pdf
#  trajectory/
# 'Volve 15_9_F-10 Drilling EOWR.pdf'
#  WL_RAW_BHPR-GR-MECH_TIME_MWD_1-9_INF_1.ASC
#  WL_RAW_BHPR-GR-MECH_TIME_MWD_1.LAS
#  WL_RAW_BHPR-GR-MECH_TIME_MWD_2.LAS
#  WL_RAW_BHPR-GR-MECH_TIME_MWD_3.LAS
#  WL_RAW_BHPR-GR-MECH_TIME_MWD_4.LAS
#  WL_RAW_BHPR-GR-MECH_TIME_MWD_5.LAS
#  WL_RAW_BHPR-GR-MECH_TIME_MWD_6.LAS
#  WL_RAW_BHPR-GR-MECH_TIME_MWD_7.LAS
#  WL_RAW_BHPR-GR-MECH_TIME_MWD_8.LAS
#  WL_RAW_BHPR-GR-MECH_TIME_MWD_9.LAS

# %%
import os
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')

# %%
files = os.listdir()
files = [s for s in files if ".LAS" in s]
files.sort()
files
# Out:
# ['WL_RAW_BHPR-GR-MECH_TIME_MWD_1.LAS',
#  'WL_RAW_BHPR-GR-MECH_TIME_MWD_2.LAS',
#  'WL_RAW_BHPR-GR-MECH_TIME_MWD_3.LAS',
#  'WL_RAW_BHPR-GR-MECH_TIME_MWD_4.LAS',
#  'WL_RAW_BHPR-GR-MECH_TIME_MWD_5.LAS',
#  'WL_RAW_BHPR-GR-MECH_TIME_MWD_6.LAS',
#  'WL_RAW_BHPR-GR-MECH_TIME_MWD_7.LAS',
#  'WL_RAW_BHPR-GR-MECH_TIME_MWD_8.LAS',
#  'WL_RAW_BHPR-GR-MECH_TIME_MWD_9.LAS']

# %%
[s for s in files if "_2" in s]
# Out:
# ['WL_RAW_BHPR-GR-MECH_TIME_MWD_2.LAS']

# %%
dfs = []
for elements in files:
    try:
        df = sc.time_indexed_LAS(elements)
    except:
        df = sc.new_time_indexed_LAS(elements)
    dfs.append(df)
# Out:
# File: WL_RAW_BHPR-GR-MECH_TIME_MWD_1.LAS
#
# Total rows :  34201
# Columns:
#  ['DEPT' 'BPOS' 'BVEL' 'BONB' 'GRM1' 'HKLD' 'ROP5' 'SWOB' 'RPM' 'TQA'
#  'SPM1' 'SPM2' 'SPM3' 'SPPA' 'TFLO' 'TRPM_RT' 'STUCK_RT' 'Stick_RT'
#  'SHKPK_RT' 'DateTime']
# Initial depth: 176.0605
# Initial date: 10-April-2009
# DeltaTime: 0 days 00:00:10
#
#
# File: WL_RAW_BHPR-GR-MECH_TIME_MWD_2.LAS
#
# Total rows :  13141
# Columns:
#  ['TIME' 'DEPTH' 'BLKP' 'ECD' 'PVEL' 'ROP' 'RPM' 'SHKRSK' 'SPPA' 'STICK'
#  'SWOB' 'TFLO' 'TRPM' 'GR_CAL' 'STOR' 'HKLA' 'DHAT' 'DateTime']
# Initial depth: 1009.8475
# Initial date: 21-April-2009
# DeltaTime: 0 days 00:00:10
#
#
# File: WL_RAW_BHPR-GR-MECH_TIME_MWD_3.LAS
#
# Total rows :  54361
# Columns:
#  ['TIME' 'DEPTH' 'BLKP' 'ECD' 'PVEL' 'ROP' 'RPM' 'SHKRSK' 'SPPA' 'STICK'
#  'SWOB' 'TFLO' 'TRPM' 'GR_CAL' 'STOR' 'HKLA' 'DHAT' 'DateTime']
# Initial depth: -999.25
# Initial date: 23-April-2009
# DeltaTime: 0 days 00:00:10
#
#
# File: WL_RAW_BHPR-GR-MECH_TIME_MWD_4.LAS
#
# Total rows :  14698
# Columns:
#  ['DEPT' 'ROP5' 'ARC_GR_RT' 'BPOS' 'BVEL' 'SWOB' 'HKLD' 'TQA' 'RPM'
#  'Stick_RT' 'CRPM_RT' 'TFLO' 'TRPM_RT' 'SPPA' 'SHKRSK_RT' 'SHKPK_RT'
#  'ECD_ARC' 'APRS_ARC' 'ATMP' 'DateTime']
# Initial depth: 296.6532
# Initial date: 05-May-2009
# DeltaTime: 0 days 00:00:10
#
#
# File: WL_RAW_BHPR-GR-MECH_TIME_MWD_5.LAS
#
# Total rows :  27181
# Columns:
#  ['DEPT' 'ROP5' 'ARC_GR_RT' 'BPOS' 'BVEL' 'SWOB' 'HKLD' 'TQA' 'RPM'
#  'Stick_RT' 'CRPM_RT' 'TFLO' 'TRPM_RT' 'SPPA' 'SHKRSK_RT' 'SHKPK_RT'
#  'ECD_ARC' 'APRS_ARC' 'ATMP' 'DateTime']
# Initial depth: 527.9707
# Initial date: 07-May-2009
# DeltaTime: 0 days 00:00:10
#
#
# File: WL_RAW_BHPR-GR-MECH_TIME_MWD_6.LAS
#
# Total rows :  26281
# Columns:
#  ['DEPT' 'ROP5' 'ARC_GR_RT' 'BPOS' 'BVEL' 'SWOB' 'HKLD' 'TQA' 'RPM'
#  'Stick_RT' 'CRPM_RT' 'TFLO' 'TRPM_RT' 'SPPA' 'SHKRSK_RT' 'SHKPK_RT'
#  'ECD_ARC' 'APRS_ARC' 'ATMP' 'DateTime']
# Initial depth: nan
# Initial date: 11-May-2009
# DeltaTime: 0 days 00:00:10
#
#
# File: WL_RAW_BHPR-GR-MECH_TIME_MWD_7.LAS
#
# Total rows :  40651
# Columns:
#  ['DEPT' 'ROP5' 'INCL_CONT_RT' 'GRMA_BHC_RT' 'HKLD' 'SWOB' 'TQA' 'RPM'
#  'Stick_RT' 'SHKRSK_RT' 'DHAT' 'TRPM_RT' 'TFLO' 'SPPA' 'DHAP' 'ECD' 'BPOS'
#  'BVEL' 'UCAV_DH_ECO_RT' 'DateTime']
# Initial depth: 3394.5204
# Initial date: 18-May-2009
# DeltaTime: 0 days 00:00:10
#
#
# File: WL_RAW_BHPR-GR-MECH_TIME_MWD_8.LAS
#
# Total rows :  46153
# Columns:
#  ['DEPT' 'ROP5' 'INCL_CONT_RT' 'HKLD' 'SWOB' 'TQA' 'RPM' 'Stick_RT'
#  'SHKRSK_RT' 'TRPM_RT' 'TFLO' 'SPPA' 'BPOS' 'BVEL' 'DateTime']
# Initial depth: 3430.0329
# Initial date: 24-May-2009
# DeltaTime: 0 days 00:00:10
#
#
# File: WL_RAW_BHPR-GR-MECH_TIME_MWD_9.LAS
#
# Total rows :  23677
# Columns:
#  ['DEPT' 'ROP5' 'INCL_CONT_RT' 'GRMA_BHC_RT' 'HKLD' 'SWOB' 'TQA' 'RPM'
#  'Stick_RT' 'SHKRSK_RT' 'DHAT' 'TRPM_RT' 'TFLO' 'SPPA' 'DHAP' 'ECD' 'BPOS'
#  'BVEL' 'UCAV_DH_ECO_RT' 'DateTime']
# Initial depth: 3429.7584
# Initial date: 31-May-2009
# DeltaTime: 0 days 00:00:10

# %%
run_2 = dfs[0]
run_3 = dfs[1]
run_4 = dfs[2]
run_5 = dfs[3]
run_6 = dfs[4]
run_7 = dfs[5]
run_8 = dfs[6]
run_9 = dfs[7]
run_10 = dfs[8]

# %%
runs = [run_2,run_3,run_4,run_5,run_6,run_7,run_8,run_9,run_10]
runs_txt = ["run_2","run_3","run_4","run_5","run_6","run_7","run_8","run_9","run_10"]
sections  =  ['26"','17 1/2"','17 1/2"','12 1/4"','12 1/4"','12 1/4"','8 1/2"','8 1/2"','8 1/2"']
info = list(zip(runs_txt,sections))

# %%
list(zip(files,info))
# Out:
# [('WL_RAW_BHPR-GR-MECH_TIME_MWD_1.LAS', ('run_2', '26"')),
#  ('WL_RAW_BHPR-GR-MECH_TIME_MWD_2.LAS', ('run_3', '17 1/2"')),
#  ('WL_RAW_BHPR-GR-MECH_TIME_MWD_3.LAS', ('run_4', '17 1/2"')),
#  ('WL_RAW_BHPR-GR-MECH_TIME_MWD_4.LAS', ('run_5', '12 1/4"')),
#  ('WL_RAW_BHPR-GR-MECH_TIME_MWD_5.LAS', ('run_6', '12 1/4"')),
#  ('WL_RAW_BHPR-GR-MECH_TIME_MWD_6.LAS', ('run_7', '12 1/4"')),
#  ('WL_RAW_BHPR-GR-MECH_TIME_MWD_7.LAS', ('run_8', '8 1/2"')),
#  ('WL_RAW_BHPR-GR-MECH_TIME_MWD_8.LAS', ('run_9', '8 1/2"')),
#  ('WL_RAW_BHPR-GR-MECH_TIME_MWD_9.LAS', ('run_10', '8 1/2"'))]

# %% [markdown]
# ## Drilling events

# %%
# %%time
i = 0
for run in runs:
    sc.well_plt(run,info[i])
    i+=1
# Out:
# Plot: run_2 	Section: 26"
# Plot: run_3 	Section: 17 1/2"
# Plot: run_4 	Section: 17 1/2"
# Plot: run_5 	Section: 12 1/4"
# Plot: run_6 	Section: 12 1/4"
# Plot: run_7 	Section: 12 1/4"
# Plot: run_8 	Section: 8 1/2"
# Plot: run_9 	Section: 8 1/2"
# Plot: run_10 	Section: 8 1/2"

# %% [markdown]
# ## Date range selector

# %%
import ipywidgets as widgets
def print_date_range(date_range):
    global inf ;  inf = date_range[0]
    global sup ;  sup = date_range[1]
    return(inf,sup)   
def date_slider(data):
    dates = data.set_index("DateTime").index ; options = [(date.strftime('%d %m %H:%M'), date) for date in dates] ; index = (0, len(options)-1)
    selection_date_slider = widgets.SelectionRangeSlider(options=options,index=index,orientation='horizontal',layout={'width': '500px'},description="Date Selector")    
    widgets.interact(print_date_range,date_range=selection_date_slider)

# %% [markdown]
# ## Run 3

# %%
run_3.columns

# %%
date_slider(run_3)

# %%
sc.date_plts(['BLKP','GR_CAL','STOR',"RPM","SPPA"],run_3,info[1],inf,sup)

# %% [markdown]
# ## Well identifier and section

# %%
i = 0 
for run in runs:
    run["Well"] = "F-10"
    run["Run"] = runs_txt[i]
    i+=1

# %% [markdown]
# ## Drilling Sections

# %%
list(zip(info,files))

# %% [markdown]
# ![image.png](attachment:image.png)
# `FWR_MUD_nr_002.pdf`

# %%
depths = [207,1400,1463,2616,2825,3319,3442,3695,4911]

# %%
runs[1] = runs[1].rename({"DEPTH":"DEPT"},axis=1)
runs[2] = runs[2].rename({"DEPTH":"DEPT"},axis=1)

# %%
drill_op = []
i = 0
for run in runs:
    df = sc.drilling_process_fell(run,depths[i])
    sc.drill_flag(df,info[i])
    df = df[df["Flag"]==1]
    drill_op.append(df)
    i+=1

# %% [markdown]
# ## Drilling analysis

# %%
runs[7].columns

# %%
date_slider(runs[7])

# %%
sc.date_scatter_plts(["DEPT","Stick_RT","RPM","SWOB","ROP5",],drill_op[7],info[7],inf,sup)

# %% [markdown]
# ## `csv`files

# %%
info

# %%
filepath = "/home/luis/Desktop/Tesis/F10/CSVs"

# %%
i = 2
for file in drill_op:
    file.to_csv(filepath+"/run_"+str(i)+".csv",index=False)
    i+=1
