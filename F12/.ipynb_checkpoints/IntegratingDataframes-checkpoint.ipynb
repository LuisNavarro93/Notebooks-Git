# %% [markdown]
# # Unifying `F-12`data

# %%
cd ~/Desktop/Tesis/Notebooks-Git
# Out:
# /home/luis/Desktop/Tesis/Notebooks-Git

# %%
import Script as sc

# %%
cd ~/Desktop/Tesis/F12
# Out:
# /home/luis/Desktop/Tesis/F14

# %%
import os
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')

# %%
logs = os.listdir()
logs = [s for s in logs if ".LAS" in s]
logs.sort()
logs
# Out:
# ['WL_RAW_BHPR-GR-MECH_TIME_MWD_1.LAS',
#  'WL_RAW_BHPR-GR-MECH_TIME_MWD_2.LAS',
#  'WL_RAW_BHPR-GR-MECH_TIME_MWD_3.LAS']

# %%
i = 2
for las in logs:
    print("\nRun_"+str(i))
    sc.logs_LAS(las)
    i+=1
# Out:
# Run_2
# File: WL_RAW_BHPR-GR-MECH_TIME_MWD_1.LAS
# TIME	    .HHMMSS	       :
# DATE	    .D		       :
# DEPT        .M                 : Bit Depth 2hz
# ROP5        .M/HR              : 5ft ROP 2hz
# ARC_GR_UNC_RT.GAPI              : ARC Raw Gamma Ray, Real-Time
# BPOS        .M                 : Block Position 2hz
# BVEL        .M/HR              : Block Velocity 2hz
# SWOB        .KKGF              : Surface Weight on Bit 2hz
# HKLD        .KKGF              : Measured Hookload 2hz
# TQA         .KMN               : SRF STOR 2hz
# RPM         .RPM               : SRF SRPM 2hz
# Stick_RT    .RPM               : MWD PKtoPK RPM 2hz
# CRPM_RT     .RPM               : MWD CRPM 2hz
# TFLO        .LPM               : HSPM Total Pump Flow 2hz
# TRPM_RT     .RPM               : MWD TUR_RPM 2hz
# SPPA        .BAR               : SRF PUMPRS 2hz
# SHKRSK_RT   .----              : MWD SHKRSK 2hz
# SHK2_RT     .----              : ARC Shock Level, Real-Time
# SHK_ISONIC_RT.----              : Isonic Shock, Real-Time
# PDSHKRSK    .----              : PowerDrive Shock Risk 2hz
# SHKPK_RT    .G                 : MWD SHK_PK 2hz
# ECD_ARC     .SG                : Equivalent Circulating Density
# APRS_ARC    .BAR               : ARC Annular Pressure
# ATMP        .DEGC              : ARC Annular Temperature
# BDTI        .HR                : Job OnBottom time 2hz
# #
#
# Run_3
# File: WL_RAW_BHPR-GR-MECH_TIME_MWD_2.LAS
# TIME	    .HHMMSS	       :
# DATE	    .D		       :
# DEPT        .M                 : Bit Depth 2hz
# ROP5        .M/HR              : 5ft ROP 2hz
# ARC_GR_RT   .GAPI              : ARC Gamma Ray, Real-Time
# BPOS        .M                 : Block Position 2hz
# BVEL        .M/HR              : Block Velocity 2hz
# HKLD        .KKGF              : Measured Hookload 2hz
# SWOB        .KKGF              : Surface Weight on Bit 2hz
# TQA         .KMN               : SRF STOR 2hz
# RPM         .RPM               : SRF SRPM 2hz
# Stick_RT    .RPM               : MWD PKtoPK RPM 2hz
# SHKRSK_RT   .----              : MWD SHKRSK 2hz
# SHK2_RT     .----              : ARC Shock Level, Real-Time
# SPPA        .BAR               : SRF PUMPRS 2hz
# TFLO        .LPM               : HSPM Total Pump Flow 2hz
# TRPM_RT     .RPM               : MWD TUR_RPM 2hz
# ECD_ARC     .G/C3              : Equivalent Circulating Density
# APRS_ARC    .BAR               : ARC Annular Pressure
# ATMP        .DEGC              : ARC Annular Temperature
# SPM1        .----              : SRF SPM1 2hz
# SPM2        .----              : SRF SPM2 2hz
# SPM3        .----              : SRF SPM3 2hz
# #
#
# Run_4
# File: WL_RAW_BHPR-GR-MECH_TIME_MWD_3.LAS
# TIME	    .HHMMSS	       :
# DATE	    .D		       :
# DEPT        .M                 : Bit Depth 2hz
# ROP5        .M/HR              : 5ft ROP 2hz
# GRMA_BHC_RT .GAPI              : DVDM Gamma Ray, Real-Time
# HKLD        .KKGF              : Measured Hookload 2hz
# SPPA        .BAR               : SRF PUMPRS 2hz
# CRS_CNINC   .DEG               : CRS CNINC 2hz
# INCL_CONT_RT.DEG               : MWD Cont Inc 2hz
# SWOB        .KKGF              : Surface Weight on Bit 2hz
# TQA         .KMN               : SRF STOR 2hz
# CRPM_RT     .RPM               : MWD CRPM 2hz
# RPM         .RPM               : SRF SRPM 2hz
# Stick_RT    .RPM               : MWD PKtoPK RPM 2hz
# SHKRSK_RT   .----              : MWD SHKRSK 2hz
# SHKPK_RT    .G                 : MWD SHK_PK 2hz
# BPOS        .M                 : Block Position 2hz
# BVEL        .M/S               : Block Velocity 2hz
# DHAT        .DEGC              : Downhole Annulus Temperature
# TFLO        .LPM               : HSPM Total Pump Flow 2hz
# ECD         .G/C3              : Equivalent Circulating Density
# DHAP        .BAR               : Downhole Annulus Pressure
# TRPM_RT     .RPM               : MWD TUR_RPM 2hz
# SPM1        .----              : SRF SPM1 2hz
# SPM2        .----              : SRF SPM2 2hz
# SPM3        .----              : SRF SPM3 2hz
# #

# %%
cd ~/Desktop/Tesis/F12/CSVs
# Out:
# /home/luis/Desktop/Tesis/F14/CSVs

# %%
files = os.listdir()
files.sort()
files
# Out:
# ['run_3.csv', 'run_4.csv', 'run_5.csv']

# %%
dfs = []
for elements in files:
    df = pd.read_csv(elements)
    dfs.append(df)

# %%
run_3 = dfs[0]
run_4 = dfs[1]
run_5 = dfs[2]

# %%
runs = [run_3,run_4,run_5]
runs_txt = ["run_3","run_4","run_5"]
sections  =  ['17 1/2"','12 1/4"','8 1/2"']
info = list(zip(runs_txt,sections))
info
# Out:
# [('run_3', '17 1/2"'), ('run_4', '12 1/4"'), ('run_5', '8 1/2"')]

# %% [markdown]
# ## Log standarization

# %% [markdown]
# Logs that are constant through the BHA
# * BPOS
# * BVEL
# * DateTime
# * ROP5
# * SWOB
# * HKLD
# * TQA
# * RPM
# * Stick_RT
# * TFLO
# * SPPA
# * SHKPK_RT
# * SHKRSK_RT
# * GMRAy

# %%
i = 0 
for run in runs:
    print("\n",runs_txt[i])
    run.drop(["TRPM_RT","Flag","BONB","HDTH"],inplace=True,axis=1)
    print("Logs:\n",np.sort(run.columns.values))
    i+=1
# Out:
#  run_3
# Logs:
#  ['APRS_ARC' 'ARC_GR_UNC_RT' 'ATMP' 'BDTI' 'BPOS' 'BVEL' 'CRPM_RT' 'DEPT'
#  'DateTime' 'ECD_ARC' 'HKLD' 'PDSHKRSK' 'ROP5' 'RPM' 'Run' 'SHK2_RT'
#  'SHKPK_RT' 'SHKRSK_RT' 'SHK_ISONIC_RT' 'SPPA' 'SWOB' 'Stick_RT' 'TFLO'
#  'TQA' 'Well']
#
#  run_4
# Logs:
#  ['APRS_ARC' 'ARC_GR_RT' 'ATMP' 'BPOS' 'BVEL' 'DEPT' 'DateTime' 'ECD_ARC'
#  'HKLD' 'ROP5' 'RPM' 'Run' 'SHK2_RT' 'SHKRSK_RT' 'SPM1' 'SPM2' 'SPM3'
#  'SPPA' 'SWOB' 'Stick_RT' 'TFLO' 'TQA' 'Well']
#
#  run_5
# Logs:
#  ['BPOS' 'BVEL' 'CRPM_RT' 'CRS_CNINC' 'DEPT' 'DHAP' 'DHAT' 'DateTime' 'ECD'
#  'GRMA_BHC_RT' 'HKLD' 'INCL_CONT_RT' 'ROP5' 'RPM' 'Run' 'SHKPK_RT'
#  'SHKRSK_RT' 'SPM1' 'SPM2' 'SPM3' 'SPPA' 'SWOB' 'Stick_RT' 'TFLO' 'TQA'
#  'Well']

# %%
runs[0].drop(['APRS_ARC','ATMP','BDTI','CRPM_RT','ECD_ARC','PDSHKRSK','SHK2_RT','SHKPK_RT','SHKRSK_RT','SHK_ISONIC_RT'],axis=1,inplace=True)
runs[1].drop(['APRS_ARC','ATMP','ECD_ARC','SHK2_RT','SHKRSK_RT','SPM1','SPM2','SPM3'],axis=1,inplace=True)
runs[2].drop(['CRPM_RT','CRS_CNINC','DHAP','DHAT','ECD','INCL_CONT_RT','SHKPK_RT','SHKRSK_RT','SPM1','SPM2','SPM3'],axis=1,inplace=True)

# %%
i = 0 
for run in runs:
    print("\n",runs_txt[i])
    print("Logs:\n",np.sort(run.columns.values))
    i+=1
# Out:
#  run_3
# Logs:
#  ['ARC_GR_UNC_RT' 'BPOS' 'BVEL' 'DEPT' 'DateTime' 'HKLD' 'ROP5' 'RPM' 'Run'
#  'SPPA' 'SWOB' 'Stick_RT' 'TFLO' 'TQA' 'Well']
#
#  run_4
# Logs:
#  ['ARC_GR_RT' 'BPOS' 'BVEL' 'DEPT' 'DateTime' 'HKLD' 'ROP5' 'RPM' 'Run'
#  'SPPA' 'SWOB' 'Stick_RT' 'TFLO' 'TQA' 'Well']
#
#  run_5
# Logs:
#  ['BPOS' 'BVEL' 'DEPT' 'DateTime' 'GRMA_BHC_RT' 'HKLD' 'ROP5' 'RPM' 'Run'
#  'SPPA' 'SWOB' 'Stick_RT' 'TFLO' 'TQA' 'Well']

# %%
runs[0].rename({'ARC_GR_UNC_RT':"GR"},axis=1,inplace=True)
runs[1].rename({'ARC_GR_RT':'GR'},axis=1,inplace=True)
runs[2].rename({'GRMA_BHC_RT':"GR"},axis=1,inplace=True)

# %%
for run in runs:
    cols = ['BPOS', 'BVEL', 'DEPT', 'DateTime','GR', 'HKLD', 'ROP5','RPM', 'Run', 'SPPA', 'SWOB', 'Stick_RT','TFLO', 'TQA', 'Well']
    run = run.reindex(columns=cols)

# %%
i = 0 
for run in runs:
    print("\n",runs_txt[i])
    print("Logs:\n",np.sort(run.columns.values))
    i+=1
# Out:
#  run_3
# Logs:
#  ['BPOS' 'BVEL' 'DEPT' 'DateTime' 'GR' 'HKLD' 'ROP5' 'RPM' 'Run' 'SPPA'
#  'SWOB' 'Stick_RT' 'TFLO' 'TQA' 'Well']
#
#  run_4
# Logs:
#  ['BPOS' 'BVEL' 'DEPT' 'DateTime' 'GR' 'HKLD' 'ROP5' 'RPM' 'Run' 'SPPA'
#  'SWOB' 'Stick_RT' 'TFLO' 'TQA' 'Well']
#
#  run_5
# Logs:
#  ['BPOS' 'BVEL' 'DEPT' 'DateTime' 'GR' 'HKLD' 'ROP5' 'RPM' 'Run' 'SPPA'
#  'SWOB' 'Stick_RT' 'TFLO' 'TQA' 'Well']

# %%
sc.boxplt_logs(runs,"GR","Gamma Ray",info)
# Out:
# Gamma Ray

# %%
cols = runs[0].columns.difference(["DateTime","Run","Well"])

# %%
cols
# Out:
# Index(['BPOS', 'BVEL', 'DEPT', 'GR', 'HKLD', 'ROP5', 'RPM', 'SPPA', 'SWOB',
#        'Stick_RT', 'TFLO', 'TQA'],
#       dtype='object')

# %%
i = 0
for log in cols:
    sc.boxplt_logs(runs,cols[i],cols[i],info)
    i+=1
# Out:
# BPOS
# BVEL
# DEPT
# GR
# HKLD
# ROP5
# RPM
# SPPA
# SWOB
# Stick_RT
# TFLO
# TQA

# %% [markdown]
# ## Concatenating

# %%
df = pd.concat(runs)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47499 entries, 0 to 20784
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DEPT      47499 non-null  float64
#  1   ROP5      47325 non-null  float64
#  2   GR        45376 non-null  float64
#  3   BPOS      47499 non-null  float64
#  4   BVEL      47499 non-null  float64
#  5   SWOB      47499 non-null  float64
#  6   HKLD      47499 non-null  float64
#  7   TQA       47499 non-null  float64
#  8   RPM       47499 non-null  float64
#  9   Stick_RT  43899 non-null  float64
#  10  TFLO      47499 non-null  float64
#  11  SPPA      47499 non-null  float64
#  12  DateTime  47499 non-null  object
#  13  Well      47499 non-null  object
#  14  Run       47499 non-null  object
# dtypes: float64(12), object(3)
# memory usage: 5.8+ MB

# %%
df["DateTime"] = pd.to_datetime(df["DateTime"])
cols = df.columns.difference(["Run","Well"])
plt_df = pd.DataFrame(df,columns = cols)

# %%
# %%time
sc.well_plt(plt_df,["Whole","Whole"])
# Out:
# Plot: Whole 	Section: Whole
# CPU times: user 5.07 s, sys: 87.3 ms, total: 5.16 s
# Wall time: 5.22 s

# %%
df.to_csv(r"WellboreF14.csv",index=False)
