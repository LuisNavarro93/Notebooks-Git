# %%
cd ~/Desktop/Tesis/Notebooks-Git
# Out:
# /home/luis/Desktop/Tesis/Notebooks-Git

# %%
import Script as sc

# %% [markdown]
# # Training set construction

# %%
cd ~/Desktop/Tesis/Notebooks-Git/Training
# Out:
# /home/luis/Desktop/Tesis/Notebooks-Git/Training

# %%
import os
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')

# %%
# Dataframes directory 
f_f4 =    "/home/luis/Desktop/Tesis/F4/trajectory/WellboreF4_Incl.csv"
f_f5 =    "/home/luis/Desktop/Tesis/F5/trajectory/WellboreF5_Incl.csv"
f_f10 = "/home/luis/Desktop/Tesis/F10/trajectory/WellboreF10_Incl.csv"
f_f14 = "/home/luis/Desktop/Tesis/F14/trajectory/WellboreF14_Incl.csv"

files = [f_f4,f_f5,f_f10,f_f14]

# %%
dfs = []
for file in files:
    df=pd.read_csv(file)
    dfs.append(df)

# %%
wells_txt = ["F4","F5","F10","F14"]
wells_txt = ["F4","F5","F10","F14"]
F4 = dfs[0]
F5 = dfs[1]
F10 = dfs[2]
F14 = dfs[3]
wells = [F4,F5,F10,F14]
sections  =  ['All','All','All','All']

# %%
wells[1].drop(["ECD","an_Temp"],axis=1,inplace=True)

# %% [markdown]
# ## Columns in wellbores dataframes

# %%
i = 0
for well in wells:
    print("\nWellbore:",wells_txt[i])
    print("Logs:\n",np.sort(well.columns.values))
    print("Shape:",well.shape)
    i+=1
# Out:
# Wellbore: F4
# Logs:
#  ['BPOS' 'BVEL' 'DEPT' 'DateTime' 'GR' 'HKLD' 'ROP5' 'RPM' 'Run' 'SPPA'
#  'SWOB' 'Stick_RT' 'TFLO' 'TQA' 'Well' 'azi' 'dispEw' 'dispNs' 'dls'
#  'incl' 'tvd']
# Shape: (1881, 21)
#
# Wellbore: F5
# Logs:
#  ['BPOS' 'BVEL' 'DEPT' 'DateTime' 'GR' 'HKLD' 'ROP5' 'RPM' 'Run' 'SPPA'
#  'SWOB' 'Stick_RT' 'TFLO' 'TQA' 'Well' 'azi' 'dispEw' 'dispNs' 'dls'
#  'incl' 'tvd']
# Shape: (1118, 21)
#
# Wellbore: F10
# Logs:
#  ['BPOS' 'BVEL' 'DEPT' 'DateTime' 'GR' 'HKLD' 'ROP5' 'RPM' 'Run' 'SPPA'
#  'SWOB' 'Stick_RT' 'TFLO' 'TQA' 'Well' 'azi' 'dispEw' 'dispNs' 'dls'
#  'incl' 'tvd']
# Shape: (6788, 21)
#
# Wellbore: F14
# Logs:
#  ['BPOS' 'BVEL' 'DEPT' 'DateTime' 'GR' 'HKLD' 'ROP5' 'RPM' 'Run' 'SPPA'
#  'SWOB' 'Stick_RT' 'TFLO' 'TQA' 'Well' 'azi' 'dispEw' 'dispNs' 'dls'
#  'incl' 'tvd']
# Shape: (1106, 21)

# %%
cols = wells[0].columns.difference(["DateTime","Run","Well",'dispEw', 'dispNs'])
cols
# Out:
# Index(['BPOS', 'BVEL', 'DEPT', 'GR', 'HKLD', 'ROP5', 'RPM', 'SPPA', 'SWOB',
#        'Stick_RT', 'TFLO', 'TQA', 'azi', 'dls', 'incl', 'tvd'],
#       dtype='object')

# %% [markdown]
# ## Continuity in wellbore logs?

# %%
i = 0
for log in cols:
    sc.boxplt_logs(wells,log,cols[i],wells_txt)
    i+=1
# Out:
# BPOS
# BVEL
# DEPT
# GR
# HKLD
# ROP5
# RPM
# SPPA
# SWOB
# Stick_RT
# TFLO
# TQA
# azi
# dls
# incl
# tvd

# %% [markdown]
# Further analysis must be done to check the `BVEL` variable

# %%
cols_new = np.sort(wells[0].columns.values)
cols_new
# Out:
# array(['BPOS', 'BVEL', 'DEPT', 'DateTime', 'GR', 'HKLD', 'ROP5', 'RPM',
#        'Run', 'SPPA', 'SWOB', 'Stick_RT', 'TFLO', 'TQA', 'Well', 'azi',
#        'dispEw', 'dispNs', 'dls', 'incl', 'tvd'], dtype=object)

# %%
wells_ordered = []
for well in wells:
    df = pd.DataFrame(well,columns=cols_new)
    wells_ordered.append(df)

# %% [markdown]
# ## Concatenating DataFrames

# %%
df =pd.concat(wells_ordered)

# %%
df["DateTime"] = pd.to_datetime(df["DateTime"])

# %%
#df = df.set_index(["DateTime","Stick_RT"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10893 entries, 0 to 1105
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BPOS      10893 non-null  float64
#  1   BVEL      10893 non-null  float64
#  2   DEPT      10893 non-null  float64
#  3   DateTime  10893 non-null  datetime64[ns]
#  4   GR        10835 non-null  float64
#  5   HKLD      10893 non-null  float64
#  6   ROP5      10610 non-null  float64
#  7   RPM       10893 non-null  float64
#  8   Run       10893 non-null  object
#  9   SPPA      10893 non-null  float64
#  10  SWOB      10893 non-null  float64
#  11  Stick_RT  10893 non-null  float64
#  12  TFLO      10893 non-null  float64
#  13  TQA       10893 non-null  float64
#  14  Well      10893 non-null  object
#  15  azi       10893 non-null  float64
#  16  dispEw    10893 non-null  float64
#  17  dispNs    10893 non-null  float64
#  18  dls       10893 non-null  float64
#  19  incl      10893 non-null  float64
#  20  tvd       10893 non-null  float64
# dtypes: datetime64[ns](1), float64(18), object(2)
# memory usage: 1.8+ MB

# %%
df
# Out:
#        BPOS    BVEL    DEPT            DateTime     GR    HKLD   ROP5    RPM  \
# 0     24.83  0.0100   286.0 2007-10-13 17:12:20  68.45   92.35  32.72  130.0
# 1     24.74  0.0100   286.0 2007-10-13 17:12:30  68.45   95.99  32.86  130.0
# 2     24.65  0.0100   286.0 2007-10-13 17:12:40  68.45   95.57  32.86  119.0
# 3     24.53  0.0100   286.0 2007-10-13 17:12:50  79.40   93.10  33.37  129.0
# 4     24.45  0.0100   286.0 2007-10-13 17:13:00  79.40   92.75  33.37  130.0
# ...     ...     ...     ...                 ...    ...     ...    ...    ...
# 1101  11.10  0.0061  3730.0 2008-06-14 13:13:37  42.36  145.59  19.04  179.0
# 1102  11.02  0.0061  3730.0 2008-06-14 13:13:47  38.82  146.53  19.35  179.0
# 1103  10.97  0.0062  3730.0 2008-06-14 13:13:57  38.82  146.49  19.35  179.0
# 1104  10.92  0.0057  3730.0 2008-06-14 13:14:07  38.82  145.54  19.35  180.0
# 1105  10.85  0.0058  3730.0 2008-06-14 13:14:17  38.82  145.73  19.56  180.0
#
#         Run    SPPA  ...  Stick_RT     TFLO    TQA  Well     azi      dispEw  \
# 0     run_2   76.63  ...       9.0  3323.21   0.76   F-4  202.90   -0.843765
# 1     run_2   74.95  ...       9.0  3323.21   0.52   F-4  202.90   -0.843765
# 2     run_2   73.85  ...       9.0  2924.43   0.56   F-4  202.90   -0.843765
# 3     run_2   75.86  ...       9.0  2924.43   0.28   F-4  202.90   -0.843765
# 4     run_2   76.82  ...       9.0  3323.21   0.40   F-4  202.90   -0.843765
# ...     ...     ...  ...       ...      ...    ...   ...     ...         ...
# 1101  run_5  180.43  ...      24.0  1962.83  16.30  F-14   93.74  963.503146
# 1102  run_5  180.43  ...      90.0  1962.83  16.30  F-14   93.74  963.503146
# 1103  run_5  180.93  ...      90.0  1962.83  16.95  F-14   93.74  963.503146
# 1104  run_5  180.79  ...      90.0  1962.83  16.47  F-14   93.74  963.503146
# 1105  run_5  180.34  ...      90.0  1962.83  15.69  F-14   93.74  963.503146
#
#           dispNs       dls   incl          tvd
# 0      -3.911797  0.022772   1.84   286.415683
# 1      -3.911797  0.022772   1.84   286.415683
# 2      -3.911797  0.022772   1.84   286.415683
# 3      -3.911797  0.022772   1.84   286.415683
# 4      -3.911797  0.022772   1.84   286.415683
# ...          ...       ...    ...          ...
# 1101  314.041492  0.009173  50.26  3145.774049
# 1102  314.041492  0.009173  50.26  3145.774049
# 1103  314.041492  0.009173  50.26  3145.774049
# 1104  314.041492  0.009173  50.26  3145.774049
# 1105  314.041492  0.009173  50.26  3145.774049
#
# [10893 rows x 21 columns]

# %% [markdown]
# ## Outlier removal
# > Interquartile range method

# %% [raw]
# df_new = sc.outlier_removal(df)

# %% [raw]
# vars_plt = list(df.columns.difference(['Well',"DateTime","Run"]))

# %% [raw]
# for var in vars_plt:
#     sns.boxplot(x = df_new[var])
#     plt.show()

# %% [raw]
# df_new.info()

# %% [raw]
# df_new.reset_index(inplace=True)
# df_new.drop(["level_0","index"],axis=1,inplace=True)

# %% [raw]
# df_new

# %%
df.to_csv("TrainingV1_Incl.csv",index=False)
