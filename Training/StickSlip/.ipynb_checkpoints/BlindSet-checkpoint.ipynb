# %%
cd ~/Desktop/Tesis/Notebooks-Git
# Out:
# /home/luis/Desktop/Tesis/Notebooks-Git

# %%
import Script as sc

# %% [markdown]
# # Blind set

# %%
cd ~/Desktop/Tesis/Notebooks-Git/Training/StickSlip
# Out:
# /home/luis/Desktop/Tesis/Notebooks-Git/Training/StickSlip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
import seaborn as sns

# %%
df = pd.read_csv("/home/luis/Desktop/Tesis/F15A/trajectory/WellboreF15A_Incl.csv")

# %%
df
# Out:
#       DEPT      dispNs      dispEw   incl          tvd       dls     azi  \
# 0     1383 -186.077697  -82.026507  26.95  1353.460438  0.121378  242.67
# 1     1383 -186.077697  -82.026507  26.95  1353.460438  0.121378  242.67
# 2     1383 -186.077697  -82.026507  26.95  1353.460438  0.121378  242.67
# 3     1383 -186.077697  -82.026507  26.95  1353.460438  0.121378  242.67
# 4     1383 -186.077697  -82.026507  26.95  1353.460438  0.121378  242.67
# ...    ...         ...         ...    ...          ...       ...     ...
# 1089  3212 -708.216067 -255.742023  20.98  3024.581302  0.028015  255.56
# 1090  3212 -708.216067 -255.742023  20.98  3024.581302  0.028015  255.56
# 1091  3212 -708.216067 -255.742023  20.98  3024.581302  0.028015  255.56
# 1092  3212 -708.216067 -255.742023  20.98  3024.581302  0.028015  255.56
# 1093  3212 -708.216067 -255.742023  20.98  3024.581302  0.028015  255.56
#
#          ROP5       GR     BPOS  ...      TQA    RPM  Stick_RT       TFLO  \
# 0      5.1960  43.8910  23.5100  ...   6.4880   79.0       6.0  4010.0120
# 1      5.1960  47.2660  23.4970  ...   6.4880   79.0       6.0  4010.0120
# 2      5.1960  47.2660  23.4840  ...   6.3820   79.0       6.0  4010.0120
# 3      5.1960  43.8910  23.4670  ...   6.4180   79.0       6.0  4010.0120
# 4      5.1960  43.8910  23.4540  ...   6.8220   79.0       6.0  4010.0120
# ...       ...      ...      ...  ...      ...    ...       ...        ...
# 1089  19.8703  28.5059  18.4528  ...  21.6551  119.0     237.0  2077.1803
# 1090  19.8543  28.5059  18.4033  ...  25.4741  120.0     237.0  2077.1803
# 1091  19.8543  28.5059  18.3533  ...  24.0478  119.0     237.0  2077.1803
# 1092  19.8543  28.5059  18.2878  ...  25.2961  120.0     237.0  2077.1803
# 1093  19.8449  35.2094  18.2380  ...  25.2961  120.0     237.0  2077.1803
#
#           SPPA     ECD      HKLD             DateTime   Well     Run
# 0     188.5840  1.4320  123.8470  2008-12-11 15:18:57  F-15A   run_7
# 1     188.5840  1.4320  123.9630  2008-12-11 15:19:07  F-15A   run_7
# 2     187.9530  1.4310  124.0930  2008-12-11 15:19:17  F-15A   run_7
# 3     188.8440  1.4320  123.9580  2008-12-11 15:19:27  F-15A   run_7
# 4     188.0770  1.4320  123.8710  2008-12-11 15:19:37  F-15A   run_7
# ...        ...     ...       ...                  ...    ...     ...
# 1089  148.8256  1.3688  127.1282  2009-01-02 12:46:47  F-15A  run_10
# 1090  147.6426  1.3703  127.0785  2009-01-02 12:46:57  F-15A  run_10
# 1091  147.5314  1.3698  127.0400  2009-01-02 12:47:07  F-15A  run_10
# 1092  148.1770  1.3703  127.3261  2009-01-02 12:47:17  F-15A  run_10
# 1093  148.1770  1.3702  127.3814  2009-01-02 12:47:27  F-15A  run_10
#
# [1094 rows x 22 columns]

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.isnull(), cbar=False)
plt.show()

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1089 entries, 0 to 1093
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DEPT      1089 non-null   int64
#  1   dispNs    1089 non-null   float64
#  2   dispEw    1089 non-null   float64
#  3   incl      1089 non-null   float64
#  4   tvd       1089 non-null   float64
#  5   dls       1089 non-null   float64
#  6   azi       1089 non-null   float64
#  7   ROP5      1089 non-null   float64
#  8   GR        1089 non-null   float64
#  9   BPOS      1089 non-null   float64
#  10  BVEL      1089 non-null   float64
#  11  SWOB      1089 non-null   float64
#  12  TQA       1089 non-null   float64
#  13  RPM       1089 non-null   float64
#  14  Stick_RT  1089 non-null   float64
#  15  TFLO      1089 non-null   float64
#  16  SPPA      1089 non-null   float64
#  17  ECD       1089 non-null   float64
#  18  HKLD      1089 non-null   float64
#  19  DateTime  1089 non-null   object
#  20  Well      1089 non-null   object
#  21  Run       1089 non-null   object
# dtypes: float64(18), int64(1), object(3)
# memory usage: 195.7+ KB

# %% [markdown]
# ## Stick & Slip Severity

# %%
df_ss = sc.ss_severity(df)

# %%
sc.depth_plts(df_ss,["SWOB","RPM","Stick_RT","ss_severity","ss_categorical"])

# %%
df_ss.to_csv(r"BlindSet_Incl.csv",index=False)
