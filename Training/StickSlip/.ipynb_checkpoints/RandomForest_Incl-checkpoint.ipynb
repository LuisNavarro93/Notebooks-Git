# %%
cd ~/Desktop/Tesis/Notebooks-Git
# Out:
# /home/luis/Desktop/Tesis/Notebooks-Git

# %%
import Script as sc

# %% [markdown]
# # Random Forest

# %%
cd ~/Desktop/Tesis/Notebooks-Git/Training/StickSlip
# Out:
# /home/luis/Desktop/Tesis/Notebooks-Git/Training/StickSlip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
import seaborn as sns

# %%
df = pd.read_csv("TrainingVss_Inc.csv")

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.isnull(), cbar=False)
plt.show()

# %%
df.dropna(inplace=True)

# %%
df.drop(['dispEw','dispNs',"tvd"], axis=1,inplace=True)

# %%
plt.figure(figsize=(15,10))
matrix = np.triu(df.drop(['ss_severity','ss_categorical'], axis=1).corr())
sns.heatmap(df.drop(['ss_severity','ss_categorical'], axis=1).corr(), annot=True, mask=matrix,fmt = '.1g',linewidths=2,vmin=-1, vmax=1, center= 0,cbar=False)
plt.show()

# %%
df.columns
# Out:
# Index(['BPOS', 'BVEL', 'DEPT', 'DateTime', 'GR', 'HKLD', 'ROP5', 'RPM', 'Run',
#        'SPPA', 'SWOB', 'Stick_RT', 'TFLO', 'TQA', 'Well', 'azi', 'dls', 'incl',
#        'Sections', 'ss_severity', 'ss_categorical', 'ss_categorical_txt'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10595 entries, 0 to 10892
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   BPOS                10595 non-null  float64
#  1   BVEL                10595 non-null  float64
#  2   DEPT                10595 non-null  float64
#  3   DateTime            10595 non-null  object
#  4   GR                  10595 non-null  float64
#  5   HKLD                10595 non-null  float64
#  6   ROP5                10595 non-null  float64
#  7   RPM                 10595 non-null  float64
#  8   Run                 10595 non-null  object
#  9   SPPA                10595 non-null  float64
#  10  SWOB                10595 non-null  float64
#  11  Stick_RT            10595 non-null  float64
#  12  TFLO                10595 non-null  float64
#  13  TQA                 10595 non-null  float64
#  14  Well                10595 non-null  object
#  15  azi                 10595 non-null  float64
#  16  dls                 10595 non-null  float64
#  17  incl                10595 non-null  float64
#  18  Sections            10595 non-null  object
#  19  ss_severity         10595 non-null  float64
#  20  ss_categorical      10595 non-null  int64
#  21  ss_categorical_txt  10595 non-null  object
# dtypes: float64(16), int64(1), object(5)
# memory usage: 1.9+ MB

# %% [markdown]
# ## Splitting sets

# %%
from sklearn.model_selection import train_test_split

# %%
x_cols = df.columns.difference(['Well','Sections','ss_severity','ss_categorical','ss_categorical_txt',"DateTime","Run","Stick_RT"])
x_cols
# Out:
# Index(['BPOS', 'BVEL', 'DEPT', 'GR', 'HKLD', 'ROP5', 'RPM', 'SPPA', 'SWOB',
#        'TFLO', 'TQA', 'azi', 'dls', 'incl'],
#       dtype='object')

# %%
X = df[x_cols]
Y = df["ss_categorical"]
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=.1, random_state=2)

# %%
print("Predictors:\n\t",x_cols.values)
print("\nSet shapes:\t")
print("\tTraining:\n\t\tX:",x_train.shape,"\n\t\tY:",y_train.shape)
print("\tTesting:\n\t\tX:",x_test.shape,"\n\t\tY:",y_test.shape)
# Out:
# Predictors:
# 	 ['BPOS' 'BVEL' 'DEPT' 'GR' 'HKLD' 'ROP5' 'RPM' 'SPPA' 'SWOB' 'TFLO' 'TQA'
#  'azi' 'dls' 'incl']
#
# Set shapes:
# 	Training:
# 		X: (9535, 14)
# 		Y: (9535,)
# 	Testing:
# 		X: (1060, 14)
# 		Y: (1060,)

# %% [markdown]
# ## Random Forest Classifier
# for training set

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
# %%time
rf = RandomForestClassifier(n_estimators=100,max_depth=None, min_samples_split=4,
                            min_samples_leaf=2,max_features='auto', bootstrap=True, 
                            n_jobs=-1,random_state=2).fit(x_train,y_train)
# Out:
# CPU times: user 5.3 s, sys: 100 ms, total: 5.4 s
# Wall time: 2.88 s

# %%
y_pred = rf.predict(x_test)

# %%
print("Accuracy:",round((accuracy_score(y_test, y_pred)*100),4),"%")
# Out:
# Accuracy: 97.2642 %

# %%
feat = np.sort(rf.feature_importances_)

# %%
plt.figure(figsize=(10,15))
plt.pie(feat,labels=x_cols,autopct='%1.1f%%')
plt.title("Feature importance")
plt.show()

# %% [markdown]
# ## Prediction

# %%
df_rf = df
df_rf["Count"] = np.arange(len(df))

# %%
df_rf["rf"] = rf.predict(X)

# %%
plt.figure(figsize = (20,10))
plt.scatter(df_rf["Count"],df_rf["ss_categorical"],label="Original")
plt.scatter(df_rf["Count"],df_rf["rf"],label="Prediction")
plt.ylabel("S&S severity category")
plt.legend()
plt.show()

# %% [markdown]
# ## ROC Curve

# %%
from sklearn.metrics import classification_report

# %%
report = classification_report(y_test,y_pred)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       940
#            1       0.88      0.68      0.77        44
#            2       0.87      0.81      0.84        32
#            3       1.00      0.86      0.93        44
#
#     accuracy                           0.97      1060
#    macro avg       0.93      0.84      0.88      1060
# weighted avg       0.97      0.97      0.97      1060

# %%
probas = rf.predict_proba(x_test)

# %%
from sklearn.metrics import roc_curve, auc

# get false and true positive rates
fpr, tpr, thresholds = roc_curve(y_test, probas[:,0], pos_label=0)

# %%
# get area under the curve
roc_auc = auc(fpr, tpr)

# %%
# PLOT ROC curve
plt.figure(dpi=150)
plt.plot(fpr, tpr, lw=1, color='green', label=f'AUC = {roc_auc:.3f}')
plt.title('ROC Curve for RF classifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate (Recall)')
plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.legend()
plt.show()

# %%
class_names = df["ss_categorical_txt"].unique()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support
cm = confusion_matrix(y_test, y_pred) 
cm_df = pd.DataFrame(cm,index = [class_names],columns = [class_names])

# %%
plt.figure(dpi=150)
sns.heatmap(cm_df, annot=True,cmap="rocket_r")
plt.title('Random Forest Classifier \nAccuracy:{0:.4f}'.format(accuracy_score(y_test, y_pred)))
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %% [markdown]
# # Blind Set
# predicting F-10 well

# %%
bl = pd.read_csv(r"BlindSet.csv")

# %%
bl.head()
# Out:
#         DEPT     BPOS    BVEL       GR      HKLD     ROP5  SWOB    RPM  \
# 0  1104.8008  39.9192  0.0021  34.3871  100.2842   7.9547  6.72  203.0
# 1  1104.8294  39.8910  0.0034  34.3871  100.0538   7.9547  6.95  204.0
# 2  1104.8713  39.8494  0.0049  40.1183  100.0407   7.9547  6.96  204.0
# 3  1104.9110  39.8093  0.0042  40.1183   99.1559  10.4199  7.85  203.0
# 4  1104.9438  39.7767  0.0034  28.6559   98.8223  10.4199  8.18  203.0
#
#        TQA      SPPA       TFLO  Stick_RT             DateTime  Well    Run  \
# 0  12.7988  148.9276  3981.0049      75.0  2009-04-13 20:16:49  F-10  run_2
# 1  13.3826  147.3801  3981.0049      75.0  2009-04-13 20:16:59  F-10  run_2
# 2  16.3141  148.6527  3981.0049      45.0  2009-04-13 20:17:09  F-10  run_2
# 3  15.8104  151.1948  3981.0049      45.0  2009-04-13 20:17:19  F-10  run_2
# 4  15.8104  151.1948  3981.0049       9.0  2009-04-13 20:17:29  F-10  run_2
#
#    ss_severity  ss_categorical ss_categorical_txt
# 0    18.472906               0        None or Low
# 1    18.382353               0        None or Low
# 2    11.029412               0        None or Low
# 3    11.083744               0        None or Low
# 4     2.216749               0        None or Low

# %%
bl_predict = pd.DataFrame(bl,columns=x_test.columns)

# %%
bl_predict.head()
# Out:
#       BPOS    BVEL       DEPT       GR      HKLD     ROP5    RPM      SPPA  \
# 0  39.9192  0.0021  1104.8008  34.3871  100.2842   7.9547  203.0  148.9276
# 1  39.8910  0.0034  1104.8294  34.3871  100.0538   7.9547  204.0  147.3801
# 2  39.8494  0.0049  1104.8713  40.1183  100.0407   7.9547  204.0  148.6527
# 3  39.8093  0.0042  1104.9110  40.1183   99.1559  10.4199  203.0  151.1948
# 4  39.7767  0.0034  1104.9438  28.6559   98.8223  10.4199  203.0  151.1948
#
#    SWOB       TFLO      TQA  azi  dls  incl
# 0  6.72  3981.0049  12.7988  NaN  NaN   NaN
# 1  6.95  3981.0049  13.3826  NaN  NaN   NaN
# 2  6.96  3981.0049  16.3141  NaN  NaN   NaN
# 3  7.85  3981.0049  15.8104  NaN  NaN   NaN
# 4  8.18  3981.0049  15.8104  NaN  NaN   NaN

# %%
print("Predictors:\n\t",bl_predict.columns)
print("\nSet shape:",bl_predict.shape)
# Out:
# Predictors:
# 	 Index(['BPOS', 'BVEL', 'DEPT', 'GR', 'HKLD', 'ROP5', 'RPM', 'SPPA', 'SWOB',
#        'TFLO', 'TQA', 'azi', 'dls', 'incl'],
#       dtype='object')
#
# Set shape: (58997, 14)

# %%
y_bl = pd.to_numeric(bl["ss_categorical"])

# %%
bl_pred = rf.predict(bl_predict)
bl["Prediction"] = bl_pred
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-43518af64464> in <module>
# ----> 1 bl_pred = rf.predict(bl_predict)
#       2 bl["Prediction"] = bl_pred
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     627             The predicted classes.
#     628         """
# --> 629         proba = self.predict_proba(X)
#     630
#     631         if self.n_outputs_ == 1:
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in predict_proba(self, X)
#     671         check_is_fitted(self)
#     672         # Check data
# --> 673         X = self._validate_X_predict(X)
#     674
#     675         # Assign chunk of trees to jobs
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in _validate_X_predict(self, X)
#     419         check_is_fitted(self)
#     420
# --> 421         return self.estimators_[0]._validate_X_predict(X, check_input=True)
#     422
#     423     @property
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in _validate_X_predict(self, X, check_input)
#     386         """Validate X whenever one tries to predict, apply, predict_proba"""
#     387         if check_input:
# --> 388             X = check_array(X, dtype=DTYPE, accept_sparse="csr")
#     389             if issparse(X) and (X.indices.dtype != np.intc or
#     390                                 X.indptr.dtype != np.intc):
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     642
#     643         if force_all_finite:
# --> 644             _assert_all_finite(array,
#     645                                allow_nan=force_all_finite == 'allow-nan')
#     646
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      94                 not allow_nan and not np.isfinite(X).all()):
#      95             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 96             raise ValueError(
#      97                     msg_err.format
#      98                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
print("Accuracy:",round((accuracy_score(y_bl, bl_pred)*100),4),"%")

# %%
bl["Count"] = np.arange(len(bl))

# %%
plt.figure(figsize = (20,10))
plt.scatter(bl["Count"],bl["ss_categorical"],label="Original")
plt.scatter(bl["Count"],bl["Prediction"],label="Prediction")
plt.ylabel("S&S severity category")
plt.legend()
plt.show()

# %%
bl.columns

# %%
def depth_plts(data,list_):
    plt.style.use("bmh")
    fig,axes = plt.subplots(1,len(list_),figsize=(10,12),sharey=True)
    for i,log in enumerate(list_):
        axes[i].scatter(data[list_[i]],data["DEPT"],marker = "*",s = 0.5,color="steelblue")
        axes[i].set_xlabel(log,fontsize=15)
        axes[i].invert_yaxis()
        if log == "ss_categorical":
            axes[i].scatter(data[list_[i]],data["DEPT"],marker = "*",color="steelblue",s = 1,label = "Original")
            axes[i].scatter(data["Prediction"],data["DEPT"],marker = "*",label = "Predicion",s = 1,color = "red",alpha=.6)
            axes[i].set_xlabel(log,fontsize=15)
            axes[i].legend()
            #axes[i].invert_yaxis()
            
    axes[0].set_ylabel("Depth",fontsize=15)
    plt.tight_layout()

# %%
depth_plts(bl,["SWOB","RPM","Stick_RT","ss_severity","ss_categorical"])
