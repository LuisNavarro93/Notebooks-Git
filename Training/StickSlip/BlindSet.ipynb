# %%
cd ~/Desktop/Tesis/Notebooks-Git
# Out:
# /home/luis/Desktop/Tesis/Notebooks-Git

# %%
import Script as sc

# %% [markdown]
# # Blind set

# %%
cd ~/Desktop/Tesis/Notebooks-Git/Training/StickSlip
# Out:
# /home/luis/Desktop/Tesis/Notebooks-Git/Training/StickSlip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
import seaborn as sns

# %%
df = pd.read_csv("/home/luis/Desktop/Tesis/F10/CSVs/WellboreF10.csv")

# %%
df.head()
# Out:
#        DEPT     BPOS  BVEL  GR     HKLD     ROP5   SWOB   RPM     TQA  \
# 0  207.2570  21.6031   0.0 NaN  88.5734  39.4406  10.93  59.0  2.3232
# 1  207.2573  21.6028   0.0 NaN  88.5700  39.4406  10.93  59.0  1.7944
# 2  207.2577  21.6024   0.0 NaN  88.4923  39.4406  11.01  59.0  1.7944
# 3  207.2577  21.6024   0.0 NaN  88.3982  39.4406  11.10  60.0  1.1824
# 4  207.2577  21.6024   0.0 NaN  88.2763  39.4406  11.23  59.0  1.7731
#
#       SPPA       TFLO  Stick_RT             DateTime  Well    Run
# 0  95.8616  3473.5011       NaN  2009-04-11 00:01:09  F-10  run_2
# 1  97.2516  3473.5011       NaN  2009-04-11 00:01:19  F-10  run_2
# 2  97.2516  3473.5011       NaN  2009-04-11 00:01:29  F-10  run_2
# 3  94.3203  3473.5011       NaN  2009-04-11 00:01:39  F-10  run_2
# 4  96.6555  3473.5011       NaN  2009-04-11 00:01:49  F-10  run_2

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.isnull(), cbar=False)
plt.show()

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73218 entries, 9 to 101623
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DEPT      73218 non-null  float64
#  1   BPOS      73218 non-null  float64
#  2   BVEL      73218 non-null  float64
#  3   GR        73218 non-null  float64
#  4   HKLD      73218 non-null  float64
#  5   ROP5      73218 non-null  float64
#  6   SWOB      73218 non-null  float64
#  7   RPM       73218 non-null  float64
#  8   TQA       73218 non-null  float64
#  9   SPPA      73218 non-null  float64
#  10  TFLO      73218 non-null  float64
#  11  Stick_RT  73218 non-null  float64
#  12  DateTime  73218 non-null  object
#  13  Well      73218 non-null  object
#  14  Run       73218 non-null  object
# dtypes: float64(12), object(3)
# memory usage: 8.9+ MB

# %% [markdown]
# ## Stick & Slip Severity

# %%
df_ss = sc.ss_severity(df)

# %%
sc.depth_plts(df_ss,["SWOB","RPM","Stick_RT","ss_severity","ss_categorical"])

# %%
df_mod = df_ss[df_ss["DEPT"]>1000]
df_mod = df_mod[df_ss["DEPT"]<4000]
# Out:
# <ipython-input-19-47c556372068>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_mod = df_mod[df_ss["DEPT"]<4000]

# %%
sc.depth_plts(df_mod,["SWOB","RPM","Stick_RT","ss_severity","ss_categorical"])

# %%
df_mod.to_csv(r"BlindSet.csv",index=False)
