# %%
cd ~/Desktop/Tesis/Notebooks-Git
# Out:
# /home/luis/Desktop/Tesis/Notebooks-Git

# %%
import Script as sc

# %% [markdown]
# # Stick&Slip analysis

# %%
cd ~/Desktop/Tesis/Notebooks-Git/Training/StickSlip
# Out:
# /home/luis/Desktop/Tesis/Notebooks-Git/Training/StickSlip

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')

# %%
df = pd.read_csv("/home/luis/Desktop/Tesis/Notebooks-Git/Training/TrainingV1.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186065 entries, 0 to 186064
# Data columns (total 15 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   BPOS      186065 non-null  float64
#  1   BVEL      186065 non-null  float64
#  2   DEPT      186065 non-null  float64
#  3   DateTime  186065 non-null  object
#  4   GR        181333 non-null  float64
#  5   HKLD      186065 non-null  float64
#  6   ROP5      185378 non-null  float64
#  7   RPM       186065 non-null  float64
#  8   Run       186065 non-null  object
#  9   SPPA      186065 non-null  float64
#  10  SWOB      186065 non-null  float64
#  11  Stick_RT  174643 non-null  float64
#  12  TFLO      186065 non-null  float64
#  13  TQA       186065 non-null  float64
#  14  Well      186065 non-null  object
# dtypes: float64(12), object(3)
# memory usage: 21.3+ MB

# %%
df.describe().transpose()
# Out:
#              count         mean         std       min        25%        50%  \
# BPOS      186065.0    23.794915   12.700349    0.8126    13.0876    23.8975
# BVEL      186065.0     3.380307   10.938616 -187.7979     0.0028     0.0062
# DEPT      186065.0  2455.784306  789.461714  225.7241  1909.2403  2667.7096
# GR        181333.0    64.767000   41.485181    0.0000    28.9900    57.8300
# HKLD      186065.0   133.462194   18.121770   58.2302   120.3758   133.7400
# ROP5      185378.0    23.211062   17.538055    0.7106    10.0779    20.0979
# RPM       186065.0   142.662903   44.342191   21.0000   129.0000   159.0000
# SPPA      186065.0   190.907812   42.625984 -728.4633   175.3800   199.1436
# SWOB      186065.0     4.747791    3.593681 -133.8011     2.1965     4.4216
# Stick_RT  174643.0    50.350813   67.255245    0.0000     9.0000    21.0000
# TFLO      186065.0  2960.948548  800.678022   44.3100  2104.7023  3367.5200
# TQA       186065.0    14.017052   15.797388 -971.0449    10.3465    14.2753
#
#                 75%        max
# BPOS        34.7290    50.5090
# BVEL         0.0100   490.3050
# DEPT      3040.1404  3792.1993
# GR          94.4626   522.9700
# HKLD       143.4100   186.5285
# ROP5        32.6400   259.0400
# RPM        170.0000   263.0000
# SPPA       215.8109   439.0982
# SWOB         6.9528    87.7975
# Stick_RT    60.0000   381.0000
# TFLO      3500.4523  4583.4420
# TQA         18.6661    34.8810

# %% [raw]
# df.drop(["DateTime"],axis=1,inplace=True)

# %%
sns.set(font_scale=1.5)
plt.figure(figsize=(20,10))
sns.violinplot(data=(df.drop(["DateTime"],axis=1)), x="Well", y="Stick_RT", hue="Run",inner="quart", linewidth=1)
sns.despine(left=True)

# %% [markdown]
# ## Section identifier per well

# %%
df_f4 = df[df["Well"]=="F-4"]

# %%
Runs = df_f4["Run"].tolist()
sections = []
for element in Runs:
    if element == "run_2":
        v = '17 1/2"' #Double check 
    elif element == "run_3":
        v = '12 1/4"'
    elif (element == "run_4") or (element == "run_5"):
        v = '8 1/2"'
    sections.append(v)

# %%
df_f4["Sections"] = sections
# Out:
# <ipython-input-11-eb8c15972f62>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_f4["Sections"] = sections

# %%
df_f5 = df[df["Well"]=="F-5"]

# %%
Runs = df_f5["Run"].tolist()
sections = []
for element in Runs:
    if element == "run_2":
        v = '17 1/2"'
    elif element == "run_3":
        v = '12 1/4"'
    elif (element == "run_4") or (element == "run_5"):
        v = '8 1/2"'
    sections.append(v)

# %%
df_f5["Sections"] = sections
# Out:
# <ipython-input-14-ed1f17070074>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_f5["Sections"] = sections

# %%
df_f14 = df[df["Well"]=="F-14"]

# %%
Runs = df_f14["Run"].tolist()
sections = []
for element in Runs:
    if element == "run_3":
        v = '17 1/2"'
    elif element == "run_4":
        v = '12 1/4"'
    elif element == "run_5":
        v = '8 1/2"'
    sections.append(v)

# %%
df_f14["Sections"] = sections
# Out:
# <ipython-input-17-7a1eed7a32cb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_f14["Sections"] = sections

# %%
frames = [df_f4,df_f5,df_f14]
df_mod = pd.concat(frames)

# %%
sns.set(font_scale=1.5)
plt.figure(figsize=(20,10))
sns.violinplot(data=(df_mod.drop(["DateTime"],axis=1)), x="Well", y="Stick_RT", hue="Sections",inner="quart", linewidth=1)
plt.legend(loc="upper left",title="Section")
sns.despine(left=True)

# %% [markdown]
# ## Stick & Slip Severity

# %%
df_ss = sc.ss_severity(df_mod)

# %%
df_ss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186065 entries, 0 to 186064
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   BPOS                186065 non-null  float64
#  1   BVEL                186065 non-null  float64
#  2   DEPT                186065 non-null  float64
#  3   DateTime            186065 non-null  object
#  4   GR                  181333 non-null  float64
#  5   HKLD                186065 non-null  float64
#  6   ROP5                185378 non-null  float64
#  7   RPM                 186065 non-null  float64
#  8   Run                 186065 non-null  object
#  9   SPPA                186065 non-null  float64
#  10  SWOB                186065 non-null  float64
#  11  Stick_RT            174643 non-null  float64
#  12  TFLO                186065 non-null  float64
#  13  TQA                 186065 non-null  float64
#  14  Well                186065 non-null  object
#  15  Sections            186065 non-null  object
#  16  ss_severity         174643 non-null  float64
#  17  ss_categorical      186065 non-null  int64
#  18  ss_categorical_txt  186065 non-null  object
# dtypes: float64(13), int64(1), object(5)
# memory usage: 33.4+ MB

# %%
sc.depth_plts(df_mod,["SWOB","RPM","Stick_RT","ss_severity","ss_categorical"])

# %%
sns.set(font_scale=1.5)
plt.figure(figsize=(20,10))
sns.violinplot(data=(df_mod.drop(["DateTime"],axis=1)), x="Well", y="DEPT", hue="ss_categorical_txt",inner="quart", linewidth=1)
plt.gca().invert_yaxis()
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=1,title="S&S Classification")
sns.despine(left=True)

# %% [raw]
# df_ss.to_csv(r"TrainingVss.csv",index=False)
