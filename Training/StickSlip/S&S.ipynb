# %%
cd ~/Desktop/Tesis/Notebooks-Git
# Out:
# /home/luis/Desktop/Tesis/Notebooks-Git

# %%
import Script as sc

# %% [markdown]
# # Stick&Slip analysis

# %%
cd ~/Desktop/Tesis/Notebooks-Git/Training/StickSlip
# Out:
# /home/luis/Desktop/Tesis/Notebooks-Git/Training/StickSlip

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')

# %%
df = pd.read_csv("/home/luis/Desktop/Tesis/Notebooks-Git/Training/TrainingV2.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131949 entries, 0 to 131948
# Data columns (total 15 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   DateTime  131949 non-null  object
#  1   Stick_RT  127363 non-null  float64
#  2   BPOS      131949 non-null  float64
#  3   BVEL      131949 non-null  float64
#  4   DEPT      131949 non-null  float64
#  5   GR        130244 non-null  float64
#  6   HKLD      131949 non-null  float64
#  7   ROP5      131706 non-null  float64
#  8   RPM       131949 non-null  float64
#  9   Run       131949 non-null  object
#  10  SPPA      131949 non-null  float64
#  11  SWOB      131949 non-null  float64
#  12  TFLO      131949 non-null  float64
#  13  TQA       131949 non-null  float64
#  14  Well      131949 non-null  object
# dtypes: float64(12), object(3)
# memory usage: 15.1+ MB

# %%
df.describe().transpose()
# Out:
#              count         mean         std       min        25%        50%  \
# Stick_RT  127363.0    52.505924   69.573242    0.0000     9.0000    24.0000
# BPOS      131949.0    24.198885   12.786797    0.8140    13.3400    24.4447
# BVEL      131949.0     0.005623    0.004026   -0.0080     0.0023     0.0055
# DEPT      131949.0  2649.411747  665.366407  619.2600  2159.2681  2762.6980
# GR        130244.0    60.822767   33.752188    0.0000    33.0625    53.6216
# HKLD      131949.0   136.822567   17.499819   95.3900   122.7997   136.5589
# ROP5      131706.0    21.091719   13.490232    0.7822     9.5363    19.8234
# RPM       131949.0   159.476760   22.742083   68.0000   150.0000   169.0000
# SPPA      131949.0   198.094653   23.482094  114.7400   180.4908   202.2407
# SWOB      131949.0     4.855097    3.155439   -4.9365     2.3854     4.5960
# TFLO      131949.0  2838.967956  718.998771  908.1484  2104.2465  3101.6665
# TQA       131949.0    15.826167    5.754073   -0.1500    11.6000    15.6955
#
#                 75%        max
# Stick_RT    60.0000   381.0000
# BPOS        35.5100    49.7791
# BVEL         0.0084     0.0208
# DEPT      3147.5154  3792.1993
# GR          88.7260   192.5156
# HKLD       146.9626   177.9539
# ROP5        30.1522    66.4800
# RPM        179.0000   192.0000
# SPPA       212.2346   276.3513
# SWOB         6.9372    14.0708
# TFLO      3500.4522  4583.4420
# TQA         19.6082    31.1438

# %% [raw]
# df.drop(["DateTime"],axis=1,inplace=True)

# %%
sns.set(font_scale=1.5)
plt.figure(figsize=(20,10))
sns.violinplot(data=(df.drop(["DateTime"],axis=1)), x="Well", y="Stick_RT", hue="Run",inner="quart", linewidth=1)
sns.despine(left=True)

# %% [markdown]
# ## Section identifier per well

# %%
df_f4 = df[df["Well"]=="F-4"]

# %%
Runs = df_f4["Run"].tolist()
sections = []
for element in Runs:
    if element == "run_2":
        v = '17 1/2"' #Double check 
    elif element == "run_3":
        v = '12 1/4"'
    elif (element == "run_4") or (element == "run_5"):
        v = '8 1/2"'
    sections.append(v)

# %%
df_f4["Sections"] = sections
# Out:
# <ipython-input-11-eb8c15972f62>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_f4["Sections"] = sections

# %%
df_f5 = df[df["Well"]=="F-5"]

# %%
Runs = df_f5["Run"].tolist()
sections = []
for element in Runs:
    if element == "run_2":
        v = '17 1/2"'
    elif element == "run_3":
        v = '12 1/4"'
    elif (element == "run_4") or (element == "run_5"):
        v = '8 1/2"'
    sections.append(v)

# %%
df_f5["Sections"] = sections
# Out:
# <ipython-input-14-ed1f17070074>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_f5["Sections"] = sections

# %%
df_f14 = df[df["Well"]=="F-14"]

# %%
Runs = df_f14["Run"].tolist()
sections = []
for element in Runs:
    if element == "run_3":
        v = '17 1/2"'
    elif element == "run_4":
        v = '12 1/4"'
    elif element == "run_5":
        v = '8 1/2"'
    sections.append(v)

# %%
df_f14["Sections"] = sections
# Out:
# <ipython-input-17-7a1eed7a32cb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_f14["Sections"] = sections

# %%
frames = [df_f4,df_f5,df_f14]
df_mod = pd.concat(frames)

# %%
sns.set(font_scale=1.5)
plt.figure(figsize=(20,10))
sns.violinplot(data=(df_mod.drop(["DateTime"],axis=1)), x="Well", y="Stick_RT", hue="Sections",inner="quart", linewidth=1)
plt.legend(loc="upper left",title="Section")
sns.despine(left=True)

# %% [markdown]
# ## Stick & Slip Severity

# %%
df_ss = sc.ss_severity(df_mod)

# %%
df_ss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131949 entries, 0 to 131948
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   DateTime            131949 non-null  object
#  1   Stick_RT            127363 non-null  float64
#  2   BPOS                131949 non-null  float64
#  3   BVEL                131949 non-null  float64
#  4   DEPT                131949 non-null  float64
#  5   GR                  130244 non-null  float64
#  6   HKLD                131949 non-null  float64
#  7   ROP5                131706 non-null  float64
#  8   RPM                 131949 non-null  float64
#  9   Run                 131949 non-null  object
#  10  SPPA                131949 non-null  float64
#  11  SWOB                131949 non-null  float64
#  12  TFLO                131949 non-null  float64
#  13  TQA                 131949 non-null  float64
#  14  Well                131949 non-null  object
#  15  Sections            131949 non-null  object
#  16  ss_severity         127363 non-null  float64
#  17  ss_categorical      131949 non-null  int64
#  18  ss_categorical_txt  131949 non-null  object
# dtypes: float64(13), int64(1), object(5)
# memory usage: 25.1+ MB

# %% [raw]
# %%time
# sns.pairplot(df_ss.dropna(), hue='ss_categorical_txt',height=4,vars=["SWOB","RPM","ROP5","GR","TFLO","DEPT"],
#              diag_kind = 'kde',corner=True)

# %% [raw]
# %%time
# sns.pairplot(df_mod.dropna(), hue='ss_categorical_txt',height=4,vars=["SWOB","RPM","ROP5","GR","TFLO","DEPT"],
#              diag_kind = 'kde',corner=True)

# %%
df_mod = df_mod[df_mod["DEPT"]>1000]

# %%
sc.depth_plts(df_mod,["SWOB","RPM","Stick_RT","ss_severity","ss_categorical"])

# %%
sns.set(font_scale=1.5)
plt.figure(figsize=(20,10))
sns.violinplot(data=(df_mod.drop(["DateTime"],axis=1)), x="Well", y="DEPT", hue="ss_categorical_txt",inner="quart", linewidth=1)
plt.gca().invert_yaxis()
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=1,title="S&S Classification")
#sns.despine(left=True)

# %% [raw]
# from scipy import stats
# plt.figure(figsize=(10,4))
# sns.jointplot(df_mod['DEPT'], df_mod['Stick_RT'],kind='kde',stat_func=stats.pearsonr)
# plt.show()

# %%
df_mod.columns

# %% [raw]
# %%time
# plt.figure(figsize=(10,13))
# sns.jointplot(data=df_mod,x='DEPT',y="Stick_RT",hue="ss_categorical_txt",kind='kde')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=1,title="S&S Classification")

# %%
# %%time
sns.set(font_scale=.8)
plt.figure(figsize=(10,6))
sns.jointplot(data=df_mod,x='DEPT',y="Stick_RT",hue="ss_categorical_txt",kind='kde')
plt.show()
# Out:
# CPU times: user 5min 53s, sys: 1.73 s, total: 5min 55s
# Wall time: 5min 53s

# %%
# %%time
sns.set(font_scale=.8)
plt.figure(figsize=(10,6))
sns.jointplot(data=df_mod,x='RPM',y="SWOB",hue="ss_categorical_txt",kind='kde')
plt.show()
# Out:
# CPU times: user 6min 52s, sys: 2 s, total: 6min 54s
# Wall time: 6min 51s

# %%
df_mod[df_mod["SWOB"] < -100]
# Out:
# Empty DataFrame
# Columns: [DateTime, Stick_RT, BPOS, BVEL, DEPT, GR, HKLD, ROP5, RPM, Run, SPPA, SWOB, TFLO, TQA, Well, Sections, ss_severity, ss_categorical, ss_categorical_txt]
# Index: []

# %%
df_mod.drop([df_mod.index[67570], df_ss.index[67569],df_ss.index[67571]],inplace=True)

# %%
df_mod[67570:67571]
# Out:
#                   DateTime  Stick_RT   BPOS    BVEL       DEPT       GR  \
# 69404  2008-02-15 02:22:52      15.0  8.656  0.0078  3305.9052  22.5625
#
#            HKLD    ROP5    RPM    Run      SPPA   SWOB       TFLO      TQA  \
# 69404  163.4436  28.389  179.0  run_5  234.6665  7.871  2214.9961  22.4517
#
#       Well Sections  ss_severity  ss_categorical ss_categorical_txt
# 69404  F-4   8 1/2"     4.189944               0        None or Low

# %%
df_mod.to_csv(r"TrainingVss.csv",index=False)
